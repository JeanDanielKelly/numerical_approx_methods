# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x_data = np.array([10, 20, 30, 40, 50, 60, 70, 80, 90])
y_data = np.array([-0.4274, -0.29998, -0.14645, 0.00153, 0.17047, 0.30593, 0.41092, 0.47730, 0.5])

# %%
plt.plot(x_data, y_data)

# %%
to_eval = 1
to_eval_2 = [1,2,3]
print(type(to_eval))
print(type(to_eval_2))
test_list = []

if type(to_eval_2) is list:
    print('yes it is a list')
    for i in to_eval_2:
        print(i)
        test_list.append(i)
else:
    print('no it is not')

print(test_list)
# Out:
# <class 'int'>
# <class 'list'>
# yes it is a list
# 1
# 2
# 3
# [1, 2, 3]

# %%
help('__init__')
# Out:
# Help on method-wrapper:
#
# __init__ = <method-wrapper '__init__' of module object>
#     Initialize self.  See help(type(self)) for accurate signature.
